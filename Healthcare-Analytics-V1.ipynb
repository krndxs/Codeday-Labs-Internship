# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Karandeep Singh\Downloads\archive (2)\healthcare\train_data.csv')
df.head()
df.dtypes
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                    object
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                   object
# Admission_Deposit                    float64
# Stay                                  object
# dtype: object

# %%
df1 = df[['Severity of Illness', 'Type of Admission']]
df1.head()
df1.dropna()
# Out:
#        Severity of Illness Type of Admission
# 0                  Extreme         Emergency
# 1                  Extreme            Trauma
# 2                  Extreme            Trauma
# 3                  Extreme            Trauma
# 4                  Extreme            Trauma
# ...                    ...               ...
# 318433            Moderate         Emergency
# 318434            Moderate            Urgent
# 318435               Minor         Emergency
# 318436               Minor            Trauma
# 318437               Minor         Emergency
#
# [318438 rows x 2 columns]

# %%
case_type = df1['Severity of Illness'].value_counts()
sns.set(style = 'whitegrid' )
sns.barplot(case_type.index, case_type.values)
plt.title('Frequency of Illness Status', fontsize = 16)
plt.ylabel('Frequency', fontsize=16)
plt.xlabel('Status', fontsize=16)
plt.show()

# %%
case_type = df1['Type of Admission'].value_counts()
sns.set(style = 'whitegrid' )
sns.barplot(case_type.index, case_type.values)
plt.title('Frequency of Addmission Type', fontsize = 16)
plt.ylabel('Freq', fontsize=16)
plt.xlabel('Type', fontsize=16)
plt.show()

# %%
df['Age'].value_counts(sort=False).plot.bar()
plt.title('Distribution of Age')
plt.ylabel('Count')
plt.xticks(fontsize = 12, rotation=0) 
plt.yticks(fontsize = 12)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000., 70000.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
df['Bed Grade'].value_counts(sort=False).plot.bar()
plt.title('Distribution of Bed Grade')
plt.ylabel('Count')
plt.xticks(fontsize = 12, rotation=0) 
plt.yticks(fontsize = 12)
# Out:
# (array([     0.,  20000.,  40000.,  60000.,  80000., 100000., 120000.,
#         140000.]),
#  <a list of 8 Text major ticklabel objects>)
